# %% [markdown]
# ## Como cálculo síntese estatística

# %%
import pandas as pd

sales = pd.read_excel("../../dataFrames/return_base.xlsx")

sales.head()
# Out:
#      Natália        Huon 1991-01-19 00:00:00        Curitiba   Chinelo   60  \
# 0  Emanuella      Fialho          1992-12-17       Fortaleza     Tênis  106
# 1    Eduarda  Figueiredo          1989-06-27       Fortaleza      Saia   83
# 2      Tayna     Coimbra          1987-12-05        Curitiba  Sandália  102
# 3       Iago    Bensdorp          1992-02-12    Porto Alegre  Pulseira  122
# 4     Paloma      Farias          1994-01-01  Rio de Janeiro   Chinelo   63
#
#     25  Unnamed: 7 Unnamed: 8  Unnamed: 9     Unnamed: 10 Unnamed: 11  \
# 0  200         1.0     Izabel     Milagre  Rio de Janeiro    Camiseta
# 1   75         2.0      Joyce       Ribas        Curitiba     Bermuda
# 2  110         3.0    Eduarda  Figueiredo       São Paulo      Casaco
# 3   30         4.0      Tayna     Coimbra        Brasília     Jaqueta
# 4   25         5.0   Patricia      Camara       Fortaleza        Saia
#
#    Unnamed: 12 Unnamed: 13
# 0         85.0  1985-01-01
# 1        150.0  1994-01-01
# ...

# %%
sales["Nome Completo"] = sales["Unnamed: 8"] + " " + sales["Unnamed: 9"]

sales.head()
# Out:
#      Natália        Huon 1991-01-19 00:00:00        Curitiba   Chinelo   60  \
# 0  Emanuella      Fialho          1992-12-17       Fortaleza     Tênis  106
# 1    Eduarda  Figueiredo          1989-06-27       Fortaleza      Saia   83
# 2      Tayna     Coimbra          1987-12-05        Curitiba  Sandália  102
# 3       Iago    Bensdorp          1992-02-12    Porto Alegre  Pulseira  122
# 4     Paloma      Farias          1994-01-01  Rio de Janeiro   Chinelo   63
#
#     25  Unnamed: 7 Unnamed: 8  Unnamed: 9     Unnamed: 10 Unnamed: 11  \
# 0  200         1.0     Izabel     Milagre  Rio de Janeiro    Camiseta
# 1   75         2.0      Joyce       Ribas        Curitiba     Bermuda
# 2  110         3.0    Eduarda  Figueiredo       São Paulo      Casaco
# 3   30         4.0      Tayna     Coimbra        Brasília     Jaqueta
# 4   25         5.0   Patricia      Camara       Fortaleza        Saia
#
#    Unnamed: 12 Unnamed: 13       Nome Completo
# ...

# %% [markdown]
# ### Estatística Agregada
#
# * Como cálculo a média de
